# %% [markdown]
# # Loading an .unv Mesh

# %% [markdown]
# ## Import modules

# %%
import sys
sys.path.append('../')

from gradient_reconstruction.util import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## Locate .unv files

# %%
structured_mesh_file_name = r"../data/structured_mesh/structured_mesh_10.unv"
triangular_mesh_file_name = r"../data/triangular_mesh/triangular_mesh_10.unv"

# %% [markdown]
# ## Load and plot the structured mesh

# %%
[nodes, elements] = unv_mesh_reader.read_unv_mesh_as_2d(structured_mesh_file_name)
mesh_plotter.plot_mesh(nodes, elements)

# %% [markdown]
# # Load and plot the triangular mesh

# %%
[nodes, elements] = unv_mesh_reader.read_unv_mesh_as_2d(triangular_mesh_file_name)
mesh_plotter.plot_mesh(nodes, elements)
